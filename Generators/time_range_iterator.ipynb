# %%
test_dict = {}
test_list = [1, 2] # Це список, він змінюваний
test_dict[test_list] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 test_dict = {}
#       2 test_list = [1, 2] # Це список, він змінюваний
# ----> 3 test_dict[test_list] = 1
#
# TypeError: unhashable type: 'list'
